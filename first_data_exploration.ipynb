# %% [markdown]
# How many unique books to scrape?
# - .unique
# What's the date range (earliest to latest ban)?
# - look at the date started and date finished
# Are there books with multiple authors?
# - .count on authors
# Any books with unclear titles that might be hard to find?
# - don't know how to find this

# %%
import pandas as pd
df = pd.read_csv("/Users/vconklin24/Desktop/DSS/full_book_details.csv")

# %%
df
# Out:
#          book_id                                              title  \
# 0     20412869.0  Study Guide: The Perks of Being a Wallflower b...
# 1     49676332.0      Study Guide: Nineteen Minutes by Jodi Picoult
# 2         6149.0                                            Beloved
# 3     19365546.0     Summary & Study Guide Fallout by Ellen Hopkins
# 4     12437190.0     Crank by Ellen Hopkins l Summary & Study Guide
# ...          ...                                                ...
# 6026  28003097.0          Georgia Peaches and Other Forbidden Fruit
# 6027  50175489.0                                    The Queer Bible
# 6028   6515763.0  How Beautiful the Ordinary: Twelve Stories of ...
# 6029  12437190.0     Crank by Ellen Hopkins l Summary & Study Guide
# 6030  23015872.0                                           Traffick
#
#       avg_rating  pages                                genres  \
# 0           3.98   38.0                               Fiction
# ...

# %%
print(df['Title'].value_counts())
# Out:
# ['Nineteen Minutes' 'The Perks of Being a Wallflower'
#  '#Pride: Championing LGBTQ Rights' ... 'The Secrets We Keep (CG)'
#  'Free Speech Handbook: A Practical Framework for Understanding Our Free Speech Protections'
#  'The Queer Bible']
# Title
# Clockwork Orange                                                 23
# Sold                                                             20
# Breathless (JN)                                                  20
# Last Night at the Telegraph Club                                 19
# A Court of Mist and Fury                                         18
#                                                                  ..
# Ghost Houses                                                      1
# Hero Heel (Series, Title Not Specified)                           1
# We Survived the Holocaust: The Bluma and Felix Goldberg Story     1
# I am Billie Jean King                                             1
# ...
