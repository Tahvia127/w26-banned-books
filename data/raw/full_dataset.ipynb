# %%
import pandas as pd
import numpy as np

# %%
import re
from datetime import datetime

def normalize_month_year_safe(date_str):
    """Normalize month-year strings to YYYY-MM-DD"""
    if pd.isna(date_str):
        return None
    
    # Remove extra spaces, non-breaking spaces, and weird characters
    date_str = re.sub(r"[\u00A0]", " ", date_str)
    date_str = date_str.strip()
    
    # Try full month name
    try:
        dt = datetime.strptime(date_str, "%B %Y")
        return dt.strftime("%Y-%m-%d")
    except:
        pass
    
    # Try abbreviated month
    try:
        dt = datetime.strptime(date_str, "%b %Y")
        return dt.strftime("%Y-%m-%d")
    except:
        print(f"⚠ Could not parse date: {date_str}")
        return None

# Load data
csv_path = 'data.csv'
df = pd.read_csv(csv_path)
print(f"Loaded {len(df)} books")

# Normalize dates
df['Ban Date Normalized'] = df['Ban Date'].apply(normalize_month_year_safe)

# Clean data (remove rows with invalid dates)
df = df.dropna(subset=['Ban Date Normalized', 'Title', 'State'])
print(f"After cleaning: {len(df)} books with valid dates")

# Save cleaned version
df.to_csv('data_clean.csv', index=False)
print("✓ Saved cleaned data to 'data_clean.csv'")
print(df[['Title', 'Ban Date', 'Ban Date Normalized']].head())
# Out:
# Loaded 22658 books
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Spring 2023
# ⚠ Could not parse date: Fall 2022
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: Fall 2023
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: July 2024 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# ⚠ Could not parse date: January 2025 - June 2025
# After cleaning: 21913 books with valid dates
# ✓ Saved cleaned data to 'data_clean.csv'
#                                                Title    Ban Date  \
# 0             Sloppy Firsts (Jessica Darling Series)  April 2022
# 1                       Outlander (Outlander Series)  April 2022
# 2                             Gender Queer: A Memoir  April 2022
# 3  The Family Fletcher Takes Rock Island (Family ...  April 2022
# 4                               Thirteen Reasons Why  April 2022
#
#   Ban Date Normalized
# 0          2022-04-01
# 1          2022-04-01
# 2          2022-04-01
# 3          2022-04-01
# 4          2022-04-01

# %%
import sys
sys.path.append('../../scripts')

from script import collect_all_books

# Run the full collection
results_df = collect_all_books(
    input_csv='data_clean.csv',  # Use the cleaned file with normalized dates
    output_csv='google_trends_complete.csv',
    sleep_between_books=2  # 2 seconds between books
)
# Out:
# Found 21913 books to process
# Collecting data:   0%|          | 10/21913 [00:49<29:40:59,  4.88s/it]
# Progress saved: 10/21913 books completed
# Collecting data:   0%|          | 20/21913 [01:38<30:22:07,  4.99s/it]
# Progress saved: 20/21913 books completed
# Collecting data:   0%|          | 30/21913 [02:27<30:30:17,  5.02s/it]
# Progress saved: 30/21913 books completed
# Collecting data:   0%|          | 40/21913 [03:16<29:35:34,  4.87s/it]
# Progress saved: 40/21913 books completed
# Collecting data:   0%|          | 50/21913 [04:05<29:26:30,  4.85s/it]
# Progress saved: 50/21913 books completed
# Collecting data:   0%|          | 60/21913 [04:53<29:41:01,  4.89s/it]
# Progress saved: 60/21913 books completed
# Collecting data:   0%|          | 70/21913 [05:43<30:05:21,  4.96s/it]
# Progress saved: 70/21913 books completed
# Collecting data:   0%|          | 80/21913 [06:32<30:02:41,  4.95s/it]
# Progress saved: 80/21913 books completed
# Collecting data:   0%|          | 90/21913 [07:17<27:14:25,  4.49s/it]
# Progress saved: 90/21913 books completed
# Collecting data:   0%|          | 100/21913 [08:06<29:50:09,  4.92s/it]
# Progress saved: 100/21913 books completed
# Collecting data:   1%|          | 110/21913 [08:55<30:08:24,  4.98s/it]
# Progress saved: 110/21913 books completed
# Collecting data:   1%|          | 120/21913 [09:43<28:45:52,  4.75s/it]
# Progress saved: 120/21913 books completed
# Collecting data:   1%|          | 130/21913 [10:31<30:03:20,  4.97s/it]
# Progress saved: 130/21913 books completed
# Collecting data:   1%|          | 140/21913 [11:23<32:20:00,  5.35s/it]
# Progress saved: 140/21913 books completed
# Collecting data:   1%|          | 150/21913 [12:14<31:02:06,  5.13s/it]
# Progress saved: 150/21913 books completed
# Collecting data:   1%|          | 160/21913 [13:05<31:06:49,  5.15s/it]
# Progress saved: 160/21913 books completed
# Collecting data:   1%|          | 170/21913 [13:57<31:43:19,  5.25s/it]
# Progress saved: 170/21913 books completed
# Collecting data:   1%|          | 180/21913 [14:49<31:31:11,  5.22s/it]
# Progress saved: 180/21913 books completed
# Collecting data:   1%|          | 190/21913 [15:41<32:22:16,  5.36s/it]
# Progress saved: 190/21913 books completed
# Collecting data:   1%|          | 200/21913 [16:30<29:59:36,  4.97s/it]
# Progress saved: 200/21913 books completed
# Collecting data:   1%|          | 210/21913 [17:21<30:29:31,  5.06s/it]
# Progress saved: 210/21913 books completed
# Collecting data:   1%|          | 220/21913 [18:12<30:43:03,  5.10s/it]
# Progress saved: 220/21913 books completed
# Collecting data:   1%|          | 230/21913 [19:01<30:31:30,  5.07s/it]
# Progress saved: 230/21913 books completed
# Collecting data:   1%|          | 240/21913 [19:53<30:33:48,  5.08s/it]
# Progress saved: 240/21913 books completed
# Collecting data:   1%|          | 250/21913 [20:44<30:54:18,  5.14s/it]
# Progress saved: 250/21913 books completed
# Collecting data:   1%|          | 260/21913 [21:36<31:15:46,  5.20s/it]
# Progress saved: 260/21913 books completed
# Collecting data:   1%|          | 270/21913 [22:28<31:24:28,  5.22s/it]
# Progress saved: 270/21913 books completed
# Collecting data:   1%|▏         | 280/21913 [23:21<31:29:04,  5.24s/it]
# Progress saved: 280/21913 books completed
# Collecting data:   1%|▏         | 290/21913 [24:10<30:04:16,  5.01s/it]
# Progress saved: 290/21913 books completed
# Collecting data:   1%|▏         | 300/21913 [24:59<30:37:24,  5.10s/it]
# Progress saved: 300/21913 books completed
# Collecting data:   1%|▏         | 310/21913 [25:50<30:27:32,  5.08s/it]
# Progress saved: 310/21913 books completed
# Collecting data:   1%|▏         | 320/21913 [26:41<30:52:20,  5.15s/it]
# Progress saved: 610/21913 books completed
# Collecting data:   3%|▎         | 620/21913 [51:47<30:45:38,  5.20s/it]
# Progress saved: 620/21913 books completed
# Collecting data:   3%|▎         | 630/21913 [52:38<30:18:31,  5.13s/it]
# Progress saved: 630/21913 books completed
# Collecting data:   3%|▎         | 640/21913 [53:28<29:46:03,  5.04s/it]
# Progress saved: 640/21913 books completed
# Collecting data:   3%|▎         | 650/21913 [54:19<30:01:36,  5.08s/it]
# Progress saved: 650/21913 books completed
# Collecting data:   3%|▎         | 660/21913 [55:12<30:24:06,  5.15s/it]
# Progress saved: 660/21913 books completed
# Collecting data:   3%|▎         | 670/21913 [56:01<28:45:25,  4.87s/it]
# Progress saved: 670/21913 books completed
# Collecting data:   3%|▎         | 680/21913 [56:52<29:46:32,  5.05s/it]
# Progress saved: 680/21913 books completed
# Collecting data:   3%|▎         | 690/21913 [57:45<31:07:51,  5.28s/it]
# Progress saved: 690/21913 books completed
# Collecting data:   3%|▎         | 700/21913 [1:01:48<216:10:23, 36.69s/it]
# Progress saved: 700/21913 books completed
# Collecting data:   3%|▎         | 701/21913 [1:03:08<31:50:35,  5.40s/it]
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# File ~/Documents/google_trends_analysis/data/raw/../../scripts/script.py:215, in get_trends_data_update(book_title, ban_date_str, retries, timeout)
#     213 try:
#     214     # Get BEFORE ban data with timeout
# --> 215     pytrends.build_payload([book_title], timeframe=before_timeframe, geo='US')
#     216     before_df = pytrends.interest_over_time()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pytrends/request.py:189, in TrendReq.build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     188 # get tokens
# --> 189 self._tokens()
#     190 return
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pytrends/request.py:195, in TrendReq._tokens(self)
#     194 # make the request and parse the returned json
# --> 195 widget_dicts = self._get_data(
#     196     url=TrendReq.GENERAL_URL,
#     197     method=TrendReq.POST_METHOD,
#     198     params=self.token_payload,
#     199     trim_chars=4,
#     200 )['widgets']
#     201 # order of the json matters...
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pytrends/request.py:159, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     158 if response.status_code == status_codes.codes.too_many_requests:
# --> 159     raise exceptions.TooManyRequestsError.from_response(response)
#     160 raise exceptions.ResponseError.from_response(response)
#
# TooManyRequestsError: The request failed: Google returned a response with code 429
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 from script import collect_all_books
#       6 # Run the full collection
# ----> 7 results_df = collect_all_books(
#       8     input_csv='data_clean.csv',  # Use the cleaned file with normalized dates
#       9     output_csv='google_trends_complete.csv',
#      10     sleep_between_books=2  # 2 seconds between books
#      11 )
#
# File ~/Documents/google_trends_analysis/data/raw/../../scripts/script.py:347, in collect_all_books(input_csv, output_csv, sleep_between_books)
#     344 ban_date = row['Ban Date Normalized']       # Adjust column name as needed
#     346 # Collect data
# --> 347 result = get_trends_data_update(book_title, ban_date)
#     348 if result:
#     349     result['state'] = row.get('State', 'Unknown')  # Add state if available
#
# File ~/Documents/google_trends_analysis/data/raw/../../scripts/script.py:282, in get_trends_data_update(book_title, ban_date_str, retries, timeout)
#     280 if attempt < retries - 1:
#     281     logging.warning(f"Rate limit for {book_title}. Waiting before retry {attempt + 2}/{retries}")
# --> 282     time.sleep(20)
#     283 else:
#     284     logging.error(f"Rate limit persists for {book_title}")
#
# KeyboardInterrupt:
